# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\lic004\\Desktop\\GitHubTesting\\data\\cleanedData.csv')
df.head(-5)
# Out:
#              Date       High        Low       Open      Close     Volume  \
# 0        1/3/2006  47.180000  46.150002  46.919998  47.080002   16296700
# 1        1/4/2006  47.240002  46.450001  47.000000  46.580002   17757900
# 2        1/5/2006  46.830002  46.320000  46.580002  46.639999   14970700
# 3        1/6/2006  46.910000  46.349998  46.799999  46.570000   12599800
# 4        1/9/2006  46.970001  46.360001  46.720001  46.599998   15619400
# ...           ...        ...        ...        ...        ...        ...
# 33731   11/9/2020  24.870001  23.299999  24.030001  24.219999  102118900
# 33732  11/10/2020  24.370001  23.860001  24.360001  24.190001   49029100
# 33733  11/11/2020  24.540001  24.010000  24.230000  24.190001   38309200
# 33734  11/12/2020  24.150000  23.559999  23.910000  23.809999   34505900
# 33735  11/13/2020  24.180000  23.730000  23.910000  24.070000   30056100
#
#       Company
# 0         BAC
# 1         BAC
# 2         BAC
# 3         BAC
# ...

# %%
lastDay = df[df['Date']=='11/20/2020']
lastDay
# Out:
#              Date        High         Low        Open       Close    Volume  \
# 3748   11/20/2020   26.950001   26.629999   26.740000   26.809999  40513900
# 7497   11/20/2020   71.629997   70.089996   70.559998   71.339996    631700
# 11246  11/20/2020   48.599998   48.070000   48.279999   48.509998    804900
# 14995  11/20/2020   52.110001   51.189999   51.830002   51.650002  15471100
# 18744  11/20/2020  224.809998  222.630005  223.000000  223.350006   1848100
# 22493  11/20/2020  115.650002  114.089996  114.430000  114.570000  12718900
# 26242  11/20/2020   58.740002   57.509998   58.360001   57.810001   7739900
# 29991  11/20/2020   52.630001   52.169998   52.450001   52.619999   1298700
# 33740  11/20/2020   26.230000   25.459999   26.040001   25.480000  38425200
#
#       Company
# 3748      BAC
# 7497      BMO
# 11246     BNS
# 14995       C
# 18744      GS
# 22493     JPM
# 26242      MS
# 29991      TD
# 33740     WFC

# %%
import squarify
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
figure(figsize=(12,10))
sizes = lastDay['Volume']
labels = lastDay['Company']
colors=['royalblue','palevioletred','goldenrod','plum','mediumaquamarine','yellowgreen','yellow','orange','lightgreen']
squarify.plot(sizes = sizes, label=labels, alpha=0.6, color=colors)
plt.title('Treemap of Bank Volumes on 11/20/2020')
plt.show()
