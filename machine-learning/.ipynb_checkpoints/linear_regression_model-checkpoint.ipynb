# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Get Data

# %%
df = pd.read_csv('C:\\Users\\lic004\\Desktop\\GitHubTesting\\Banks-Historical-Stock-Price-Analysis-Kaggle-\\data\\cleanedDataSelectedBanks.csv')
df.head()Date
# Out:
#          Date       High        Low       Open      Close      Volume Company
# 0  2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0     BAC
# 1  2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0     BAC
# 2  2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0     BAC
# 3  2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0     BAC
# 4  2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0     BAC

# %%
sns.set(rc={'figure.figsize':(7,7)})
sns.pairplot(df)

# %% [markdown]
# ## Training a Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Set variables
X = df[['High','Low','Open','Close']]
y = df['Volume']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4, random_state=101)

# %%
# Create and train the model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Model evaluation

# get the intercept
print(linear_model.intercept_)
# Out:
# 35767510.9729776

# %%
coeff_df = pd.DataFrame(linear_model.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#         Coefficient
# High   3.536546e+06
# Low   -3.857533e+06
# Open   1.953925e+05
# Close -1.183103e+05

# %%
# Model predictions

predictions = linear_model.predict(X_test)
plt.scatter(y_test, predictions)

# %%
# Residual histogram
sns.distplot((y_test-predictions),bins=50)
# Out:
# C:\Users\lic004\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
# Regression Evaluation Metrics
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 25415584.39329444
# MSE: 2389330894795920.0
# RMSE: 48880782.46914548

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Linear Regression is not a very good predictive model for volume
